# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git config --global user.email "nasipurisoumya@gmail.com"
# !git config --global user.name "Soumya Nasipuri"

# %%
# %cd '/content/drive/MyDrive/Github/TDAEssentialCodes'
# Out:
# /content/drive/MyDrive/Github/TDAEssentialCodes

# %%
# !echo "# ComputationalTopologyEssentialCodes" >> README.md
# !git init
# !git commit -m "first commit"
# !git branch -M main

# %%
username = 'Itachi1999'
git_token = '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'
repository = 'ComputationalTopologyEssentialCodes'

# %%
#Since I can't commit my github token to the github repository, I have to git ignore this file
# !echo "githubCode.ipynb" >> .gitignore

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean

# %%
# !git add . 
# !git commit -m "finally finalised github code"
# Out:
# [main b6c6485] finally finalised github code
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite githubCode.ipynb (64%)

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Itachi1999/ComputationalTopologyEssentialCodes.git (fetch)
# origin	https://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@github.com/Itachi1999/ComputationalTopologyEssentialCodes.git (push)

# %%
# !git show-ref

# %%
# !git remote remove origin

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
