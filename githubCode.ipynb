# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.email "nasipurisoumya@gmail.com"
# !git config --global user.name "Soumya Nasipuri"

# %%
# %cd '/content/drive/MyDrive/Github/TDAEssentialCodes'
# Out:
# /content/drive/MyDrive/Github/TDAEssentialCodes

# %%
# !echo "# ComputationalTopologyEssentialCodes" >> README.md
# !git init
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/Itachi1999/ComputationalTopologyEssentialCodes.git
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Github/TDAEssentialCodes/.git/
# [master (root-commit) 95d0f4e] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# %%
username = 'Itachi1999'
git_token = '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'
repository = 'ComputationalTopologyEssentialCodes'

# %%
# !git remote remove origin

# %%
# !git add .
# !git commit -m "first commit"
# !!git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# Out:
# [main 1502d5d] first commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
# []

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://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@github.com/Itachi1999/ComputationalTopologyEssentialCodes.git'

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/Itachi1999/ComputationalTopologyEssentialCodes.git (fetch)
# origin	https://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@github.com/Itachi1999/ComputationalTopologyEssentialCodes.git (push)

# %%
# !git status
# Out:
# On branch main
# nothing to commit, working tree clean
